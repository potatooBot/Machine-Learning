# %%
import pandas as pd

# %%
df=pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import math
mean_age=math.ceil( df["Age"].mean())
mean_age
# Out:
# 30

# %%
df["Age"]=df["Age"].fillna(mean_age)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le_sex=LabelEncoder()

# %%
df["encoded_sex"]=le_sex.fit_transform(df["Sex"])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
input=df.drop(["PassengerId","Survived","Name","Sex","SibSp","Parch","Ticket","Cabin","Embarked","Fare"],axis="columns")
input
# Out:
#      Pclass   Age  encoded_sex
# 0         3  22.0            1
# 1         1  38.0            0
# 2         3  26.0            0
# 3         1  35.0            0
# 4         3  35.0            1
# ..      ...   ...          ...
# 886       2  27.0            1
# 887       1  19.0            0
# 888       3  30.0            0
# 889       1  26.0            1
# 890       3  32.0            1
#
# [891 rows x 3 columns]

# %%
target=df.Survived
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(input,target,test_size=0.2)

# %%
X_train
# Out:
#      Pclass   Age  encoded_sex
# 438       1  64.0            1
# 309       1  30.0            0
# 340       2   2.0            1
# 306       1  30.0            0
# 123       2  32.5            0
# ..      ...   ...          ...
# 57        3  28.5            1
# 615       2  24.0            0
# 243       3  22.0            1
# 6         1  54.0            1
# 352       3  15.0            1
#
# [712 rows x 3 columns]

# %%
len(y_train)
# Out:
# 712

# %%
len(X_test)
# Out:
# 179

# %%
from sklearn import tree
model =tree.DecisionTreeClassifier(criterion="entropy")
model.fit(X_train.values,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
model.score(X_test,y_test)*100
# Out:
# c:\Users\kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# 79.88826815642457

# %%
model.predict([[2,27.0,1]])
# Out:
# array([0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
y_predict=model.predict(X_test.values)

# %%
cm=confusion_matrix(y_test,y_predict)
cm
# Out:
# array([[98, 13],
#        [23, 45]], dtype=int64)

# %%
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(2,2))
sn.heatmap(cm,annot=True)
plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# Text(-3.0, 0.5, 'Truth')

# %%
df["Predicted"]=model.predict(input)
df.to_csv("New_Predicted.csv",index=False)
# Out:
# c:\Users\kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
